# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from kagglehub) (2.31.0)
# Collecting tqdm (from kagglehub)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from requests->kagglehub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from requests->kagglehub) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\jokub\mambaforge\envs\tiriamasis\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglehub
# Successfully installed kagglehub-0.3.13 tqdm-4.67.1

# %%
import kagglehub
import shutil, os

dataset_path = kagglehub.dataset_download("pengcw1/market-1501")
target_dir = os.path.join(os.getcwd(), "data")
shutil.copytree(dataset_path, target_dir, dirs_exist_ok=True)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.13)
# 'c:\\Users\\jokub\\Desktop\\Tiriamasis projektas\\Tiriamasis\\data'

# %% [markdown]
# Use cuda

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

import os

os.environ['CUDA_LAUNCH_BLOCKING']="1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"
# Out:
# Using device: cuda

# %% [markdown]
# Dataset reading and display

# %%
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import torch
from torchvision.transforms import RandomErasing, ColorJitter
import os
import matplotlib.pyplot as plt
import numpy as np
path = "c:\\Users\\jokub\\Desktop\\Tiriamasis projektas\\Tiriamasis\\data\\Market-1501-v15.09.15"

class Market1501Dataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform
        self.img_paths = [os.path.join(data_dir, img) for img in os.listdir(data_dir) if img.endswith('.jpg')]
        
        self.labels = []
        for img in os.listdir(data_dir):
            if img.endswith('.jpg'):
                person_id = img.split('_')[0]
                self.labels.append(int(person_id) if person_id != '-1' else -1)

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label
    
transform = transforms.Compose([
    transforms.Resize((128, 64)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = Market1501Dataset(os.path.join(path, "bounding_box_train"), transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = Market1501Dataset(os.path.join(path, "bounding_box_test"), transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

query_dataset = Market1501Dataset(os.path.join(path, "query"), transform=transform)
query_loader = DataLoader(query_dataset, batch_size=32, shuffle=False)

#NUM_CLASSES = len(set(label for _, label in train_loader.dataset))    

def show_images(images, labels, num_images=10):
    images = images * torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1)
    images = images.clamp(0, 1)

    indices = np.random.choice(images.shape[0], num_images, replace=False)
    selected_images = images[indices]
    selected_labels = labels[indices]

    plt.figure(figsize=(15, 5))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(selected_images[i].permute(1, 2, 0).cpu().numpy())
        plt.title(f"ID: {selected_labels[i].item()}")
        plt.axis("off")
    plt.show()

images, labels = next(iter(train_loader))
show_images(images, labels, num_images=10)

# %% [markdown]
# Models classes

# %%
import torch
import math
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import resnet50, ResNet50_Weights
from torch.utils.data import DataLoader
from torchvision import transforms
from PIL import Image
import os
from sklearn.metrics.pairwise import cosine_similarity


class ReIDModel(nn.Module):
    def __init__(self, embedding_dim=512):
        super(ReIDModel, self).__init__()
        self.backbone = resnet50(weights=ResNet50_Weights.DEFAULT)
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, embedding_dim)
        self.embedding_dim = embedding_dim

    def forward(self, x):
        x = self.backbone(x)
        x = F.normalize(x, p=2, dim=1)
        return x

class TripletLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(TripletLoss, self).__init__()
        self.margin = margin

    def forward(self, anchor, positive, negative):
        pos_dist = F.pairwise_distance(anchor, positive, p=2)
        neg_dist = F.pairwise_distance(anchor, negative, p=2)
        loss = torch.relu(pos_dist - neg_dist + self.margin)
        return loss.mean()
    
class ReIDModelClasses(nn.Module):
    def __init__(self, num_classes):
        super(ReIDModelClasses, self).__init__()
        self.backbone = resnet50(weights=ResNet50_Weights.DEFAULT)
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, 1501)

    def forward(self, x):
        return self.backbone(x)


def create_triplets(images, labels):
    triplets = []
    labels = labels.cpu().numpy()
    for i in range(len(images)):
        anchor, label = images[i], labels[i]
        positive_idx = np.where(labels == label)[0]
        negative_idx = np.where(labels != label)[0]
        if len(positive_idx) > 1 and len(negative_idx) > 0:
            positive = images[np.random.choice(positive_idx)]
            negative = images[np.random.choice(negative_idx)]
            triplets.append((anchor, positive, negative))
    return triplets

# %% [markdown]
# Training methods

# %%
def hard_triplet_mining(anchor_emb, positive_emb, negative_emb, margin):
    """Compute the hardest positives and negatives for triplet loss."""
    pos_dist = F.pairwise_distance(anchor_emb, positive_emb, p=2)
    neg_dist = F.pairwise_distance(anchor_emb, negative_emb, p=2)

    hard_positive = torch.max(pos_dist)
    hard_negative = torch.min(neg_dist)

    triplet_loss = torch.relu(hard_positive - hard_negative + margin)
    return triplet_loss

def train_model_triplet(train_loader, device, num_epochs=100, lr=0.0003, margin=1.0, patience=5):
    model = ReIDModel(embedding_dim=512)
    model = model.to(device)
    criterion = TripletLoss(margin=margin)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
    best_loss = math.inf
    patience_counter = 0

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        num_triplets = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            triplets = create_triplets(images, labels)
            if len(triplets) == 0:
                continue

            for anchor, positive, negative in triplets:
                anchor, positive, negative = (
                    anchor.unsqueeze(0),
                    positive.unsqueeze(0),
                    negative.unsqueeze(0),
                )
                anchor_emb = model(anchor)
                positive_emb = model(positive)
                negative_emb = model(negative)

                loss = hard_triplet_mining(anchor_emb, positive_emb, negative_emb, margin)
                running_loss += loss.item()
                num_triplets += 1

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        epoch_loss = running_loss / num_triplets if num_triplets > 0 else 0.0

        if epoch_loss < best_loss:
            best_loss = epoch_loss
            patience_counter = 0
            torch.save(model.state_dict(), "best_model_triplet.pth")
        else:
            patience_counter += 1

        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Best Loss: {best_loss:.4f}")

        # Check for early stopping
        if patience_counter >= patience:
            print("Early stopping triggered!")
            break

        scheduler.step()

    print("Training complete.")
    return model

def train_model_backbone(train_loader, device, num_epochs=10, lr=0.0003):
    model = ReIDModelClasses(num_classes=1501)
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    best_loss = float("inf")

    for epoch in range(num_epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)

        if epoch_loss < best_loss:
            best_loss = epoch_loss
            torch.save(model.state_dict(), 'best_model_backbone.pth')

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")

    print("Training completed.")
    return model

# %% [markdown]
# Embed generation methods

# %%
def generate_embeddings_triplet(model, data_loader, device):
    model.eval()
    embeddings, labels = [], []
    with torch.no_grad():
        for images, lbls in data_loader:
            images = images.to(device)
            emb = model(images)
            embeddings.append(emb.cpu())
            labels.append(lbls)
    return torch.cat(embeddings), torch.cat(labels)

def extract_features(model, dataloader, device):
    model.eval()
    features, labels = [], []
    with torch.no_grad():
        for images, lbls in dataloader:
            images, lbls = images.to(device), lbls.to(device)
            outputs = model(images)  
            features.append(outputs.cpu())
            labels.append(lbls.cpu()) 
    return torch.cat(features), torch.cat(labels)

# %% [markdown]
# Evaluation methods

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def evaluate_embeddings_triplet(query_embeddings, gallery_embeddings):
    similarity_matrix = cosine_similarity(query_embeddings, gallery_embeddings)
    return similarity_matrix

def batched_cosine_similarity(query_features, gallery_features, batch_size=128):
    num_queries = query_features.shape[0]
    num_gallery = gallery_features.shape[0]
    similarity_matrix = np.zeros((num_queries, num_gallery))

    for i in range(0, num_queries, batch_size):
        query_batch = query_features[i:i + batch_size]
        similarity_matrix[i:i + batch_size] = cosine_similarity(query_batch, gallery_features)

    return similarity_matrix

def evaluate(query_features, query_labels, gallery_features, gallery_labels):
    query_features = query_features.numpy()
    query_labels = query_labels.numpy()
    gallery_features = gallery_features.numpy()
    gallery_labels = gallery_labels.numpy()
    
    similarity_matrix = batched_cosine_similarity(query_features, gallery_features)
    
    # Sort the similarity matrix to find the top matches
    sorted_indices = np.argsort(-similarity_matrix, axis=1)
    
    # Compute Rank-1 accuracy
    rank1 = np.sum(gallery_labels[sorted_indices[:, 0]] == query_labels)
    rank1_accuracy = rank1 / len(query_labels)
    
    # Compute mAP
    average_precision = []
    
    for i in range(len(query_labels)):
        relevant = gallery_labels[sorted_indices[i]] == query_labels[i]
        
        if relevant.sum() == 0:  # Skip if no relevant items
            continue
        
        # Compute precision at each rank using vectorized operations
        cumulative_retrieved = np.cumsum(relevant)
        precision_at_k = cumulative_retrieved / (np.arange(1, len(sorted_indices[i]) + 1))
        
        # Only include precision values where relevant items were retrieved
        relevant_precision = precision_at_k[relevant]
        
        if relevant_precision.size > 0:
            average_precision.append(relevant_precision.mean())
    
    mAP = np.mean(average_precision) if average_precision else 0
    
    return rank1_accuracy, mAP

# %%
model = train_model_triplet(train_loader, device, num_epochs=10)
# Out:
# Epoch [1/10], Loss: 0.4690, Best Loss: 0.4690
# Epoch [2/10], Loss: 0.4818, Best Loss: 0.4690
# Epoch [3/10], Loss: 0.5852, Best Loss: 0.4690
# Epoch [4/10], Loss: 0.4839, Best Loss: 0.4690
# Epoch [5/10], Loss: 0.5300, Best Loss: 0.4690
# Epoch [6/10], Loss: 0.5126, Best Loss: 0.4690
# Early stopping triggered!
# Training complete.

# %%
model2 = train_model_backbone(train_loader, device, num_epochs=10)
# Out:
# Epoch 1/10, Loss: 3.9177
# Epoch 2/10, Loss: 0.4946
# Epoch 3/10, Loss: 0.0952
# Epoch 4/10, Loss: 0.0272
# Epoch 5/10, Loss: 0.0280
# Epoch 6/10, Loss: 0.0632
# Epoch 7/10, Loss: 0.0852
# Epoch 8/10, Loss: 0.0674
# Epoch 9/10, Loss: 0.0362
# Epoch 10/10, Loss: 0.0231
# Training completed.

# %%
query_embeddings, query_labels = generate_embeddings_triplet(model, query_loader, device)
gallery_embeddings, gallery_labels = generate_embeddings_triplet(model, test_loader, device)

# %%
similarity_matrix = evaluate_embeddings_triplet(query_embeddings, gallery_embeddings)
print(f"Similarity Matrix Shape: {similarity_matrix.shape}")
# Out:
# Similarity Matrix Shape: (3368, 19732)

# %%
gallery_features, gallery_labels = extract_features(model2, test_loader, device)
query_features, query_labels = extract_features(model2, query_loader, device)

# %%
rank1, mAP = evaluate(query_features, query_labels, gallery_features, gallery_labels)
print(f"Rank-1 Accuracy: {rank1:.4f}, mAP: {mAP:.4f}")
# Out:
# Rank-1 Accuracy: 0.9587, mAP: 0.4638

# %%
for i in range(len(query_labels)):
    relevant = (gallery_labels == query_labels[i]).sum()
    print(f"Query {i}: {relevant} relevant matches")
# Out:
# Query 0: 59 relevant matches
# Query 1: 59 relevant matches
# Query 2: 59 relevant matches
# Query 3: 59 relevant matches
# Query 4: 59 relevant matches
# Query 5: 59 relevant matches
# Query 6: 10 relevant matches
# Query 7: 10 relevant matches
# Query 8: 10 relevant matches
# Query 9: 10 relevant matches
# Query 10: 10 relevant matches
# Query 11: 22 relevant matches
# Query 12: 22 relevant matches
# Query 13: 22 relevant matches
# Query 14: 22 relevant matches
# Query 15: 22 relevant matches
# Query 16: 42 relevant matches
# Query 17: 42 relevant matches
# Query 18: 42 relevant matches
# Query 19: 42 relevant matches
# Query 20: 42 relevant matches
# Query 21: 42 relevant matches
# Query 22: 9 relevant matches
# Query 23: 9 relevant matches
# Query 24: 9 relevant matches
# Query 25: 9 relevant matches
# Query 26: 9 relevant matches
# Query 27: 6 relevant matches
# Query 28: 6 relevant matches
# Query 29: 6 relevant matches
# Query 30: 8 relevant matches
# Query 31: 8 relevant matches
# Query 32: 8 relevant matches
# Query 33: 5 relevant matches
# Query 34: 5 relevant matches
# Query 35: 5 relevant matches
# Query 36: 5 relevant matches
# Query 37: 5 relevant matches
# Query 38: 29 relevant matches
# Query 39: 29 relevant matches
# Query 40: 29 relevant matches
# Query 41: 29 relevant matches
# Query 42: 29 relevant matches
# Query 43: 29 relevant matches
# Query 44: 29 relevant matches
# Query 45: 29 relevant matches
# Query 46: 29 relevant matches
# Query 47: 29 relevant matches
# Query 48: 29 relevant matches
# Query 49: 6 relevant matches
# Query 50: 6 relevant matches
# Query 51: 6 relevant matches
# Query 155: 14 relevant matches
# Query 156: 14 relevant matches
# Query 157: 14 relevant matches
# Query 158: 32 relevant matches
# Query 159: 32 relevant matches
# Query 160: 32 relevant matches
# Query 161: 32 relevant matches
# Query 162: 32 relevant matches
# Query 163: 32 relevant matches
# Query 164: 7 relevant matches
# Query 165: 7 relevant matches
# Query 166: 7 relevant matches
# Query 167: 7 relevant matches
# Query 168: 26 relevant matches
# Query 169: 26 relevant matches
# Query 170: 26 relevant matches
# Query 171: 26 relevant matches
# Query 172: 26 relevant matches
# Query 173: 26 relevant matches
# Query 174: 6 relevant matches
# Query 175: 6 relevant matches
# Query 176: 6 relevant matches
# Query 177: 6 relevant matches
# Query 178: 17 relevant matches
# Query 179: 17 relevant matches
# Query 180: 17 relevant matches
# Query 181: 17 relevant matches
# Query 182: 17 relevant matches
# Query 183: 13 relevant matches
# Query 184: 13 relevant matches
# Query 185: 13 relevant matches
# Query 186: 13 relevant matches
# Query 187: 3 relevant matches
# Query 188: 3 relevant matches
# Query 189: 29 relevant matches
# Query 190: 29 relevant matches
# Query 191: 29 relevant matches
# Query 192: 29 relevant matches
# Query 193: 29 relevant matches
# Query 194: 29 relevant matches
# Query 195: 40 relevant matches
# Query 196: 40 relevant matches
# Query 197: 40 relevant matches
# Query 198: 40 relevant matches
# Query 199: 40 relevant matches
# Query 200: 40 relevant matches
# Query 201: 27 relevant matches
# Query 202: 27 relevant matches
# Query 203: 27 relevant matches
# Query 204: 27 relevant matches
# Query 205: 27 relevant matches
# Query 206: 27 relevant matches
# Query 207: 3 relevant matches
# Query 208: 3 relevant matches
# Query 209: 3 relevant matches
# Query 210: 2 relevant matches
# Query 211: 2 relevant matches
# Query 212: 5 relevant matches
# Query 213: 5 relevant matches
# Query 214: 5 relevant matches
# Query 215: 18 relevant matches
# Query 216: 18 relevant matches
# Query 217: 18 relevant matches
# Query 218: 40 relevant matches
# Query 219: 40 relevant matches
# Query 220: 40 relevant matches
# Query 221: 40 relevant matches
# Query 222: 40 relevant matches
# Query 223: 40 relevant matches
# Query 224: 50 relevant matches
# Query 225: 50 relevant matches
# Query 226: 50 relevant matches
# Query 227: 50 relevant matches
# Query 228: 50 relevant matches
# Query 229: 50 relevant matches
# Query 230: 56 relevant matches
# Query 231: 56 relevant matches
# Query 232: 56 relevant matches
# Query 233: 56 relevant matches
# Query 234: 56 relevant matches
# Query 235: 23 relevant matches
# Query 236: 23 relevant matches
# Query 237: 23 relevant matches
# Query 238: 23 relevant matches
# Query 239: 23 relevant matches
# Query 240: 32 relevant matches
# Query 241: 32 relevant matches
# Query 242: 32 relevant matches
# Query 243: 32 relevant matches
# Query 244: 32 relevant matches
# Query 245: 2 relevant matches
# Query 246: 2 relevant matches
# Query 247: 22 relevant matches
# Query 248: 22 relevant matches
# Query 249: 22 relevant matches
# Query 250: 22 relevant matches
# Query 251: 19 relevant matches
# Query 252: 19 relevant matches
# Query 253: 19 relevant matches
# Query 254: 19 relevant matches
# Query 255: 19 relevant matches
# Query 256: 19 relevant matches
# Query 257: 27 relevant matches
# Query 2981: 11 relevant matches
# Query 2982: 11 relevant matches
# Query 2983: 11 relevant matches
# Query 2984: 11 relevant matches
# Query 2985: 24 relevant matches
# Query 2986: 24 relevant matches
# Query 2987: 24 relevant matches
# Query 2988: 24 relevant matches
# Query 2989: 24 relevant matches
# Query 2990: 24 relevant matches
# Query 2991: 24 relevant matches
# Query 2992: 24 relevant matches
# Query 2993: 24 relevant matches
# Query 2994: 16 relevant matches
# Query 2995: 16 relevant matches
# Query 2996: 16 relevant matches
# Query 2997: 16 relevant matches
# Query 2998: 16 relevant matches
# Query 2999: 16 relevant matches
# Query 3000: 20 relevant matches
# Query 3001: 20 relevant matches
# Query 3002: 20 relevant matches
# Query 3003: 20 relevant matches
# Query 3004: 20 relevant matches
# Query 3005: 20 relevant matches
# Query 3006: 10 relevant matches
# Query 3007: 10 relevant matches
# Query 3008: 10 relevant matches
# Query 3009: 10 relevant matches
# Query 3010: 10 relevant matches
# Query 3011: 18 relevant matches
# Query 3012: 18 relevant matches
# Query 3013: 18 relevant matches
# Query 3014: 18 relevant matches
# Query 3015: 13 relevant matches
# Query 3016: 13 relevant matches
# Query 3017: 13 relevant matches
# Query 3018: 13 relevant matches
# Query 3019: 13 relevant matches
# Query 3020: 27 relevant matches
# Query 3021: 27 relevant matches
# Query 3022: 27 relevant matches
# Query 3023: 27 relevant matches
# Query 3024: 10 relevant matches
# Query 3025: 10 relevant matches
# Query 3026: 10 relevant matches
# Query 3027: 10 relevant matches
# Query 3028: 22 relevant matches
# Query 3029: 22 relevant matches
# Query 3030: 22 relevant matches
# Query 3031: 22 relevant matches
# Query 3032: 22 relevant matches
# Query 3033: 23 relevant matches
# Query 3034: 23 relevant matches
# Query 3035: 23 relevant matches
# Query 3036: 23 relevant matches
# Query 3037: 23 relevant matches
# Query 3038: 13 relevant matches
# Query 3039: 13 relevant matches
# Query 3040: 13 relevant matches
# Query 3041: 28 relevant matches
# Query 3042: 28 relevant matches
# Query 3043: 28 relevant matches
# Query 3044: 28 relevant matches
# Query 3045: 28 relevant matches
# Query 3046: 19 relevant matches
# Query 3047: 19 relevant matches
# Query 3048: 19 relevant matches
# Query 3049: 19 relevant matches
# Query 3050: 19 relevant matches
# Query 3051: 7 relevant matches
# Query 3052: 7 relevant matches
# Query 3053: 7 relevant matches
# Query 3054: 29 relevant matches
# Query 3055: 29 relevant matches
# Query 3056: 29 relevant matches
# Query 3057: 29 relevant matches
# Query 3058: 29 relevant matches
# Query 3059: 29 relevant matches
# Query 3060: 18 relevant matches
# Query 3061: 18 relevant matches
# Query 3062: 18 relevant matches
# Query 3063: 18 relevant matches
# Query 3064: 10 relevant matches
# Query 3065: 10 relevant matches
# Query 3066: 10 relevant matches
# Query 3067: 3 relevant matches
# Query 3068: 3 relevant matches
# Query 3069: 7 relevant matches
# Query 3070: 7 relevant matches
# Query 3071: 7 relevant matches
# Query 3072: 7 relevant matches
# Query 3073: 7 relevant matches
# Query 3074: 20 relevant matches
# Query 3075: 20 relevant matches
# Query 3076: 20 relevant matches
# Query 3077: 20 relevant matches
# Query 3078: 8 relevant matches
# Query 3079: 8 relevant matches
# Query 3080: 8 relevant matches
# Query 3081: 8 relevant matches
# Query 3082: 8 relevant matches
# Query 3083: 8 relevant matches
# Query 3084: 22 relevant matches
# Query 3085: 22 relevant matches
# Query 3086: 22 relevant matches
# Query 3087: 22 relevant matches
# Query 3088: 18 relevant matches
# Query 3089: 18 relevant matches
# Query 3090: 18 relevant matches
# Query 3091: 18 relevant matches
# Query 3092: 18 relevant matches
# Query 3093: 20 relevant matches
# Query 3094: 20 relevant matches
# Query 3095: 20 relevant matches
# Query 3096: 20 relevant matches
# Query 3097: 20 relevant matches
# Query 3098: 12 relevant matches
# Query 3099: 12 relevant matches
# Query 3100: 12 relevant matches
# Query 3101: 12 relevant matches
# Query 3102: 14 relevant matches
# Query 3103: 14 relevant matches
# Query 3104: 14 relevant matches
# Query 3105: 14 relevant matches
# Query 3106: 17 relevant matches
# Query 3107: 17 relevant matches
# Query 3108: 17 relevant matches
# Query 3109: 17 relevant matches
# Query 3110: 17 relevant matches
# Query 3111: 17 relevant matches
# Query 3112: 17 relevant matches
# Query 3113: 17 relevant matches
# Query 3114: 17 relevant matches
# Query 3115: 21 relevant matches
# Query 3116: 21 relevant matches
# Query 3117: 21 relevant matches
# Query 3118: 21 relevant matches
# Query 3119: 21 relevant matches
# Query 3120: 19 relevant matches
# Query 3121: 19 relevant matches
# Query 3122: 19 relevant matches
# Query 3123: 19 relevant matches
# Query 3124: 19 relevant matches
# Query 3125: 12 relevant matches
# Query 3126: 12 relevant matches
# Query 3127: 12 relevant matches
# Query 3128: 12 relevant matches
# Query 3129: 13 relevant matches
# Query 3130: 13 relevant matches
# Query 3131: 13 relevant matches
# Query 3132: 13 relevant matches
# Query 3133: 16 relevant matches
# Query 3134: 16 relevant matches
# Query 3135: 16 relevant matches
# Query 3136: 16 relevant matches
# Query 3137: 16 relevant matches
# Query 3138: 16 relevant matches
# Query 3139: 17 relevant matches
# Query 3140: 17 relevant matches
# Query 3141: 17 relevant matches
# Query 3142: 17 relevant matches
# Query 3143: 5 relevant matches
# Query 3144: 5 relevant matches
# Query 3145: 5 relevant matches
# Query 3146: 18 relevant matches
# Query 3147: 18 relevant matches
# Query 3148: 18 relevant matches
# Query 3149: 18 relevant matches
# Query 3150: 18 relevant matches
# Query 3151: 12 relevant matches
# Query 3152: 12 relevant matches
# Query 3153: 12 relevant matches
# Query 3154: 12 relevant matches
# Query 3155: 12 relevant matches
# Query 3156: 18 relevant matches
# Query 3157: 18 relevant matches
# Query 3158: 18 relevant matches
# Query 3159: 18 relevant matches
# Query 3160: 7 relevant matches
# Query 3161: 7 relevant matches
# Query 3162: 7 relevant matches
# Query 3163: 7 relevant matches
# Query 3164: 7 relevant matches
# Query 3165: 7 relevant matches
# Query 3166: 7 relevant matches
# Query 3167: 24 relevant matches
# Query 3168: 24 relevant matches
# Query 3169: 24 relevant matches
# Query 3170: 24 relevant matches
# Query 3171: 14 relevant matches
# Query 3172: 14 relevant matches
# Query 3173: 14 relevant matches
# Query 3174: 14 relevant matches
# Query 3175: 14 relevant matches
# Query 3176: 17 relevant matches
# Query 3177: 17 relevant matches
# Query 3178: 17 relevant matches
# Query 3179: 17 relevant matches
# Query 3180: 9 relevant matches
# Query 3181: 9 relevant matches
# Query 3182: 9 relevant matches
# Query 3183: 9 relevant matches
# Query 3184: 8 relevant matches
# Query 3185: 8 relevant matches
# Query 3186: 8 relevant matches
# Query 3187: 18 relevant matches
# Query 3188: 18 relevant matches
# Query 3189: 18 relevant matches
# Query 3190: 18 relevant matches
# Query 3191: 15 relevant matches
# Query 3192: 15 relevant matches
# Query 3193: 15 relevant matches
# Query 3194: 15 relevant matches
# Query 3195: 23 relevant matches
# Query 3196: 23 relevant matches
# Query 3197: 23 relevant matches
# Query 3198: 23 relevant matches
# Query 3199: 23 relevant matches
# Query 3200: 7 relevant matches
# Query 3201: 7 relevant matches
# Query 3202: 7 relevant matches
# Query 3203: 7 relevant matches
# Query 3204: 13 relevant matches
# Query 3205: 13 relevant matches
# Query 3206: 13 relevant matches
# Query 3207: 13 relevant matches
# Query 3208: 19 relevant matches
# Query 3209: 19 relevant matches
# Query 3210: 19 relevant matches
# Query 3211: 19 relevant matches
# Query 3212: 14 relevant matches
# Query 3213: 14 relevant matches
# Query 3214: 14 relevant matches
# Query 3215: 14 relevant matches
# Query 3216: 14 relevant matches
# Query 3217: 26 relevant matches
# Query 3218: 26 relevant matches
# Query 3219: 26 relevant matches
# Query 3220: 26 relevant matches
# Query 3221: 26 relevant matches
# Query 3222: 26 relevant matches
# Query 3223: 15 relevant matches
# Query 3224: 15 relevant matches
# Query 3225: 15 relevant matches
# Query 3226: 15 relevant matches
# Query 3227: 15 relevant matches
# Query 3228: 13 relevant matches
# Query 3229: 13 relevant matches
# Query 3230: 13 relevant matches
# Query 3231: 13 relevant matches
# Query 3232: 15 relevant matches
# Query 3233: 15 relevant matches
# Query 3234: 15 relevant matches
# Query 3235: 15 relevant matches
# Query 3236: 15 relevant matches
# Query 3237: 5 relevant matches
# Query 3238: 5 relevant matches
# Query 3239: 8 relevant matches
# Query 3240: 8 relevant matches
# Query 3241: 8 relevant matches
# Query 3242: 8 relevant matches
# Query 3243: 13 relevant matches
# Query 3244: 13 relevant matches
# Query 3245: 13 relevant matches
# Query 3246: 13 relevant matches
# Query 3247: 15 relevant matches
# Query 3248: 15 relevant matches
# Query 3249: 15 relevant matches
# Query 3250: 15 relevant matches
# Query 3251: 9 relevant matches
# Query 3252: 9 relevant matches
# Query 3253: 9 relevant matches
# Query 3254: 9 relevant matches
# Query 3255: 9 relevant matches
# Query 3256: 8 relevant matches
# Query 3257: 8 relevant matches
# Query 3258: 8 relevant matches
# Query 3259: 8 relevant matches
# Query 3260: 8 relevant matches
# Query 3261: 9 relevant matches
# Query 3262: 9 relevant matches
# Query 3263: 9 relevant matches
# Query 3264: 9 relevant matches
# Query 3265: 9 relevant matches
# Query 3266: 12 relevant matches
# Query 3267: 12 relevant matches
# Query 3268: 12 relevant matches
# Query 3269: 12 relevant matches
# Query 3270: 12 relevant matches
